# %%
import pandas as pd
data = pd.read_csv('test.csv')
data
# Out:
#    product_number                                      title  \
# 0         75899:                                   LaFerrari
# 1         75899:                              458 Italia GT2
# 2         75899:                                  McLaren P1
# 3         75899:                          Porsche 918 Spyder
# 4         75899:                   McLaren Mercedes Pit Stop
# 5         75899:                  Porsche 911 GT Finish Line
# 6         75899:              F14 T & Scuderia Ferrari Truck
# 7         75870:                      Chevrolet Corvette Z06
# 8         75870:                             Ford Mustang GT
# 9         75870:                     Audi R18 e-tron quattro
# 10        75870:                           Audi R8 LMS ultra
# 11        75870:                  Chevrolet Camaro Drag Race
# 12        75870:    Ford F-150 Raptor & Ford Model A Hot Rod
# 13        75870:        Porsche 919 Hybrid and 917K Pit Lane
# ...
