# %%
import requests
from bs4 import BeautifulSoup

url = 'https://bestoftelegram.com/groups/cryptocurrency'

# Send a GET request to the URL
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the top three channels
channel_elements = soup.select('.features li')

for channel_element in channel_elements:
    channel_name = channel_element.get_text(strip=True)
    channel_link = channel_element.find('a')['href']
    print(f"Channel: {channel_name}")
    print(f"Link: {channel_link}")
    print()

# %%
from bs4 import BeautifulSoup

html_code = '''
<div class="row no-gutters" style="height: auto !important;">

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0 pb-sm-5">
<div class="cgrid">
<a title="Entertainment page" href="entertainment">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/entertainment.jpg&quot;);">Entertainment</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>Epic Memes<a title="Open Epic memes" href="/channels/DailyEpicMemes"><i class="icon-telegram open-telegram"></i></a></li>
<li>Memes<a title="Open Memes" href="/channels/bestmemes"><i class="icon-telegram open-telegram"></i></a></li>
<li>Sarcasm<a title="Open Sarcasm" href="/channels/sarcasm9"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More entertainment channels" href="entertainment" class="more reuse-button-colored">More...</a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0 pb-sm-5">
<div class="cgrid">
<a title="Open cryptocurrency page" href="cryptocurrency">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/cryptocurrency.jpg&quot;);">Cryptocurrency</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>Cointelegraph<a title="Open Cointelegraph" href="/channels/cointelegraph"><i class="icon-telegram open-telegram"></i></a></li>
<li>Crypto World News<a title="Open Crypto World News" href="/channels/CryptoWorldNews"><i class="icon-telegram open-telegram"></i></a></li>
<li>Binance Announcements<a title="Open Binance Announcements" href="/channels/binance_announcements"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More cryptocurrency channels" href="cryptocurrency"><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0">
<div class="cgrid">
<a title="Open celebrity page" href="celebrity">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/celebrity.jpg&quot;);">Celebrity</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>❤️Actress Heaven❤️<a title="Open Actress Heaven channel" href="/channels/actressheaven"><i class="icon-telegram open-telegram"></i></a></li>
<li>Beautiful Girls 💋<a title="Open Beautiful Girls channel" href="/channels/Euro_Girlss"><i class="icon-telegram open-telegram"></i></a></li>
<li>Actress Fantasy<a title="Open Actress Fantasy channel" href="/channels/actresshot0"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More celebrity channels" href="celebrity"><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0">
<div class="cgrid">
<a title="Open fashion-beauty page" href="fashion-beauty">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/fashion-beauty.jpg&quot;);">Fashion and Beauty</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>Women's Look<a title="Open Womens Look" href="/channels/womenslook"><i class="icon-telegram open-telegram"></i></a></li>
<li>Men's Look<a title="Open Mens Look" href="/channels/menslooks"><i class="icon-telegram open-telegram"></i></a></li>
<li>Actress Heaven<a title="Open Actress Heaven" href="/channels/actressheaven"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More fashion-beauty channels" href="fashion-beauty"><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0">
<div class="cgrid">
<a title="Open Music page" href="music">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/music.jpg&quot;);">Music</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>💎Music Nab💎<a title="Open Music Nab" href="/channels/NABMUSICS"><i class="icon-telegram open-telegram"></i></a></li>
<li>Sick Mind's Media<a title="Open Sick Mind Media" href="/channels/SickMindsMedia"><i class="icon-telegram open-telegram"></i></a></li>
<li>English Music<a title="Open English Music" href="/channels/english_mp3s_new"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More Music channels" href="music"><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0">
<div class="cgrid">
<a title="Open game apps page" href="games-apps">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/games-apps.jpg&quot;);">Games and apps</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>AndroGaмєr<a title="Open AndroGaмєr" href="/channels/AndroGamers"><i class="icon-telegram open-telegram"></i></a></li>
<li>SOFTWARE™<a title="Open SOFTWARE" href="/channels/pcandroidsoftware"><i class="icon-telegram open-telegram"></i></a></li>
<li>Android Themes Channel<a title="Open Android Themes Channel" href="/channels/AndroidThemes"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More games-apps channels" href="games-apps"><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0">
<div class="cgrid">
<a title="Open technology page" href="technology">
<h2 class="top-side bg-img bg-overlay lazy mb-0" style="background-image: url(&quot;img/bg-img/technology.jpg&quot;);">Technology</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>
><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>

<div class="col-12 col-sm-6 col-md-4 col-lg-3 pr-5 pr-sm-0">
<div class="cgrid">
<a title="Open others page" href="others">
<h2 class="top-side bg-img bg-overlay lazy mb-0" data-src="img/bg-img/others.jpg">Others</h2>
</a>
<div class="bottom-side">
<p class="top-3 mb-0">Top 3 channels</p>
<ul class="features">
<li>Confessions<a title="Open Confessions" href="/channels/Confessionss"><i class="icon-telegram open-telegram"></i></a></li>
<li>Daily Life Hacks<a title="Open Daily Life Hacks" href="/channels/RealDailyLifeHacks"><i class="icon-telegram open-telegram"></i></a></li>
<li>English Story Page<a title="Open English Story Page" href="/channels/StoryPage"><i class="icon-telegram open-telegram"></i></a></li>
</ul>
<a title="More others channels" href="others"><div class="more reuse-button-colored">More...</div></a>
</div>
</div>
</div>
</div>
'''

soup = BeautifulSoup(html_code, 'html.parser')

categories = soup.find_all('div', class_='col-12')

for category in categories:
    title = category.find('h2').text.strip()
    url = category.find('a')['href']
    channel_names = [li.text.split('Open')[0].strip() for li in category.find_all('ul', class_='features')]
    
    print('Title:', title)
    print('URL:', url)
    print('Top 3 Channels:', channel_names)
    print()
# Out:
# Title: Entertainment
# URL: entertainment
# Top 3 Channels: ['Epic Memes\nMemes\nSarcasm']
#
# Title: Cryptocurrency
# URL: cryptocurrency
# Top 3 Channels: ['Cointelegraph\nCrypto World News\nBinance Announcements']
#
# Title: Celebrity
# URL: celebrity
# Top 3 Channels: ['❤️Actress Heaven❤️\nBeautiful Girls 💋\nActress Fantasy']
#
# Title: Fashion and Beauty
# URL: fashion-beauty
# Top 3 Channels: ["Women's Look\nMen's Look\nActress Heaven"]
#
# Title: Music
# URL: music
# Top 3 Channels: ["💎Music Nab💎\nSick Mind's Media\nEnglish Music"]
#
# Title: Games and apps
# URL: games-apps
# Top 3 Channels: ['AndroGaмєr\nSOFTWARE™\nAndroid Themes Channel']
#
# Title: Technology
# URL: technology
# Top 3 Channels: ['Telegram Tips✔\nProgramming Tips 💡\nGadget News']
#
# Title: Adults
# URL: adults
# Top 3 Channels: ['Brazerss\nCINEMA 18\nPremium videos']
#
# Title: Arts and Photos
# URL: arts-photos
# Top 3 Channels: ['WALLPAPER\niWallpaper\nWallpapersGram™ HD']
#
# Title: Quotes
# ...

# %%
from selenium import webdriver

# Create a new instance of the Chrome driver
driver = webdriver.Chrome()

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." button and click it
more_button = driver.find_element_by_css_selector('.more.reuse-button-colored')
more_button.click()

# Wait for the page to load with the additional channels
# You may need to adjust the sleep duration depending on the page loading speed
import time
time.sleep(2)

# Extract the information about the channels
channels = driver.find_elements_by_css_selector('.features li')
for channel in channels:
    channel_name = channel.text
    print(channel_name)

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 10
#       7 driver.get('https://bestoftelegram.com/channels/')
#       9 # Find the "More..." button and click it
# ---> 10 more_button = driver.find_element_by_css_selector('.more.reuse-button-colored')
#      11 more_button.click()
#      13 # Wait for the page to load with the additional channels
#      14 # You may need to adjust the sleep duration depending on the page loading speed
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_css_selector'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# Create Chrome options
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run Chrome in headless mode

# Create a new instance of the Chrome driver with the headless option
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." button and click it
more_button = driver.find_element(by='css selector', value='.more.reuse-button-colored')
more_button.click()

# Wait for the page to load with the additional channels
time.sleep(2)

# Extract the information about the channels
channels = driver.find_elements(by='css selector', value='.features li')
for channel in channels:
    channel_name = channel.text
    print(channel_name)

# Close the browser
driver.quit()

# %%
from selenium import webdriver

# Create a new instance of the Chrome driver
driver = webdriver.Chrome()

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." button and click it
more_button = driver.find_element(by='css selector', value='.more.reuse-button-colored')
more_button.click()

# Wait for the page to load with the additional channels
# You may need to adjust the sleep duration depending on the page loading speed
import time
time.sleep(2)

# Extract the information about the channels
channels = driver.find_elements(by='css selector', value='.features li')
for channel in channels:
    channel_name = channel.text
    print(channel_name)

# Close the browser
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# Create Chrome options
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run Chrome in headless mode

# Create a new instance of the Chrome driver with the headless option
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." button and click it
more_button = driver.find_element(by='css selector', value='.more.reuse-button-colored')
more_button.click()

# Wait for the page to load with the additional channels
time.sleep(2)

# Extract the information about the channels
channel_elements = driver.find_elements(by='css selector', value='.channel-area.featured')
for channel_element in channel_elements:
    # Extract channel name
    channel_name_element = channel_element.find_element(by='css selector', value='h2.font-style1')
    channel_name = channel_name_element.text
    
    # Extract channel username
    channel_username_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i')
    channel_username = channel_username_element.text
    
    # Extract number of subscribers
    subscribers_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i.icon-users')
    subscribers = subscribers_element.text
    
    # Extract channel description
    channel_description_element = channel_element.find_element(by='css selector', value='.channel-desc p')
    channel_description = channel_description_element.text
    
    print("Channel Name:", channel_name)
    print("Username:", channel_username)
    print("Subscribers:", subscribers)
    print("Description:", channel_description)
    print()
    
# Close the browser
driver.quit()
# Out:
# Channel Name: Crypto and Finance Memes
# Username: @CryptoMemesHub
# Subscribers:
# Description: All in one channel for:
# 📌 Crypto Jokes
# 📌 Crypto Memes
# 📌 Finance Memes

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import StaleElementReferenceException
import time

# Create Chrome options
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run Chrome in headless mode

# Create a new instance of the Chrome driver with the headless option
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." buttons and click them until no more buttons are found
while True:
    try:
        more_buttons = driver.find_elements(by='css selector', value='.more.reuse-button-colored')
        if len(more_buttons) == 0:
            break
        for button in more_buttons:
            try:
                button.click()
                time.sleep(2)
            except StaleElementReferenceException:
                # If the element is stale, continue to the next iteration of the loop
                continue
    except StaleElementReferenceException:
        # If the elements are stale, break out of the loop
        break

# Extract the information about the channels
channel_elements = driver.find_elements(by='css selector', value='.channel-area.featured')
for channel_element in channel_elements:
    # Extract channel name
    channel_name_element = channel_element.find_element(by='css selector', value='h2.font-style1')
    channel_name = channel_name_element.text
    
    # Extract channel username
    channel_username_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i')
    channel_username = channel_username_element.text
    
    # Extract number of subscribers
    subscribers_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i.icon-users')
    subscribers = subscribers_element.text
    
    # Extract channel description
    channel_description_element = channel_element.find_element(by='css selector', value='.channel-desc p')
    channel_description = channel_description_element.text
    
    print("Channel Name:", channel_name)
    print("Username:", channel_username)
    print("Subscribers:", subscribers)
    print("Description:", channel_description)
    print()
    
# Close the browser
driver.quit()
# Out:
# Channel Name: Crypto and Finance Memes
# Username: @CryptoMemesHub
# Subscribers:
# Description: All in one channel for:
# 📌 Crypto Jokes
# 📌 Crypto Memes
# 📌 Finance Memes

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import StaleElementReferenceException
import time
import pandas as pd

# Create Chrome options
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run Chrome in headless mode

# Create a new instance of the Chrome driver with the headless option
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." buttons and click them until no more buttons are found
while True:
    try:
        more_buttons = driver.find_elements(by='css selector', value='.more.reuse-button-colored')
        if len(more_buttons) == 0:
            break
        for button in more_buttons:
            try:
                button.click()
                time.sleep(2)
            except StaleElementReferenceException:
                # If the element is stale, continue to the next iteration of the loop
                continue
    except StaleElementReferenceException:
        # If the elements are stale, break out of the loop
        break

# Extract the information about the channels
channel_elements = driver.find_elements(by='css selector', value='.channel-area.featured')
channel_data = []
for channel_element in channel_elements:
    # Extract channel name
    channel_name_element = channel_element.find_element(by='css selector', value='h2.font-style1')
    channel_name = channel_name_element.text
    
    # Extract channel username
    channel_username_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i')
    channel_username = channel_username_element.text
    
    # Extract number of subscribers
    subscribers_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i.icon-users')
    subscribers = subscribers_element.text
    
    # Extract channel description
    channel_description_element = channel_element.find_element(by='css selector', value='.channel-desc p')
    channel_description = channel_description_element.text
    
    channel_data.append({
        'Channel Name': channel_name,
        'Username': channel_username,
        'Subscribers': subscribers,
        'Description': channel_description
    })

# Create a DataFrame from the channel data
df = pd.DataFrame(channel_data)

# Print the DataFrame
print(df)

# Close the browser
driver.quit()
# Out:
#                Channel Name         Username Subscribers  \
# 0  Crypto and Finance Memes  @CryptoMemesHub
#
#                                          Description
# 0  All in one channel for:\n📌 Crypto Jokes\n📌 Cry...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import StaleElementReferenceException
import time
import pandas as pd

# Create Chrome options
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run Chrome in headless mode

# Create a new instance of the Chrome driver with the headless option
driver = webdriver.Chrome(options=chrome_options)

# Navigate to the webpage containing the button
driver.get('https://bestoftelegram.com/channels/')

# Find the "More..." buttons and click them until no more buttons are found
while True:
    try:
        more_buttons = driver.find_elements(by='css selector', value='.more.reuse-button-colored')
        if len(more_buttons) == 0:
            break
        for button in more_buttons:
            try:
                button.click()
                time.sleep(2)
            except StaleElementReferenceException:
                # If the element is stale, continue to the next iteration of the loop
                continue
    except StaleElementReferenceException:
        # If the elements are stale, break out of the loop
        break

# Extract the information about the channels
channel_elements = driver.find_elements(by='css selector', value='.channel-area.featured')
channel_data = []
base_url = 'https://bestoftelegram.com'
for channel_element in channel_elements:
    # Extract channel URL
    channel_link_element = channel_element.find_element(by='css selector', value='a[href*="/channels/"]')
    channel_url = base_url + channel_link_element.get_attribute('href')

    # Extract channel name
    channel_name_element = channel_element.find_element(by='css selector', value='h2.font-style1')
    channel_name = channel_name_element.text

    # Extract channel username
    channel_username_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i')
    channel_username = channel_username_element.text

    # Extract number of subscribers
    subscribers_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i.icon-users')
    subscribers = subscribers_element.text

    # Extract channel description
    channel_description_element = channel_element.find_element(by='css selector', value='.channel-desc p')
    channel_description = channel_description_element.text

    channel_data.append({
        'Channel Name': channel_name,
        'Username': channel_username,
        'Subscribers': subscribers,
        'Description': channel_description,
        'URL': channel_url
    })

# Create a DataFrame from the channel data
df = pd.DataFrame(channel_data)

# Print the DataFrame
print(df)

# Close the browser
driver.quit()
# Out:
#                Channel Name         Username Subscribers  \
# 0  Crypto and Finance Memes  @CryptoMemesHub
#
#                                          Description  \
# 0  All in one channel for:\n📌 Crypto Jokes\n📌 Cry...
#
#                                                  URL
# 0  https://bestoftelegram.comhttps://bestoftelegr...

# %%
url = 'https://bestoftelegram.com/channels/entertainment'

channel='https://bestoftelegram.com/channels/Desi_Memes_Hindi_Jokes_Indian_18'

page = requests.get(channel)

html = BeautifulSoup(page.content, 'html.parser')

html_result = html.find_all('div', class_ = 'channel-area d-flex flex-wrap justify-content-between')

channel_name_element = channel_element.find_element(by='css selector', value='h2.font-style1').text

channel_username_element = channel_element.find_element(by='css selector', value='.mb-0.color-gray i').text

# %%
channel_name_element
# Out:
# 'Crypto and Finance Memes'

# %%
from bs4 import BeautifulSoup

channel='https://bestoftelegram.com/channels/Desi_Memes_Hindi_Jokes_Indian_18'

page = requests.get(channel)


soup = BeautifulSoup(html_code, 'html.parser')

channel_id_element = soup.find('i', class_='icon-id-card-o').find_next('br').previous_sibling
category_element = soup.find('i', class_='icon-filter').find_next('a')
language_element = soup.find('i', class_='icon-language').find_next('br').previous_sibling
members_element = soup.find('i', class_='icon-users').find_next('br').previous_sibling
date_added_element = soup.find('i', class_='icon-clock').find_next('br').previous_sibling
description_element = soup.find('h2', text='Channel Description').find_next('p')

channel_id = channel_id_element.strip().split(':')[1].strip()
category = category_element.text.strip()
language = language_element.strip()
members = members_element.strip()
date_added = date_added_element.strip()
description = description_element.text.strip()

print('Channel ID:', channel_id)
print('Category:', category)
print('Language:', language)
print('Members:', members)
print('Date Added:', date_added)
print('Description:', description)
# Out:
# Channel ID: @Desi_Memes_Hindi_Jokes_Indian_18
# Category: Entertainment
# Language: Language : Hindi, English
# Members: Members : 55650
# Date Added: • Best Telegram channel for
# Description: • Best Telegram channel for
#     - Indian memes
#     - Hindi Jokes
#     - Desi Bakchodi

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

channel = 'https://bestoftelegram.com/channels/Desi_Memes_Hindi_Jokes_Indian_18'
page = requests.get(channel)

soup = BeautifulSoup(page.content, 'html.parser')

channel_id_element = soup.find('i', class_='icon-id-card-o').find_next('br').previous_sibling
category_element = soup.find('i', class_='icon-filter').find_next('a')
language_element = soup.find('i', class_='icon-language').find_next('br').previous_sibling
members_element = soup.find('i', class_='icon-users').find_next('br').previous_sibling
date_added_element = soup.find('i', class_='icon-clock').find_next('br').previous_sibling
description_element = soup.find('h2', text='Channel Description').find_next('p')

channel_id = channel_id_element.strip().split(':')[1].strip()
category = category_element.text.strip()
language = language_element.strip()
members = members_element.strip()
date_added = date_added_element.strip()
description = description_element.text.strip()

data = {
    'Channel ID': [channel_id],
    'Category': [category],
    'Language': [language],
    'Members': [members],
    'Date Added': [date_added],
    'Description': [description],
    'Link': [channel]
}

df = pd.DataFrame(data)
df
# Out:
#                           Channel ID       Category  \
# 0  @Desi_Memes_Hindi_Jokes_Indian_18  Entertainment
#
#                     Language          Members                   Date Added  \
# 0  Language : Hindi, English  Members : 55650  • Best Telegram channel for
#
#                                          Description  \
# 0  • Best Telegram channel for \n- Indian memes \...
#
#                                                 Link
# 0  https://bestoftelegram.com/channels/Desi_Memes...

# %%
from bs4 import BeautifulSoup

html_code = '''
<div class="channel-area d-flex flex-wrap justify-content-between" style="padding:10px 15px;margin-bottom:10px;">
    <a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
    </a>
    <div class="channel-head d-flex align-items-center" style="padding-right:10px;">
        <a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
            <picture>
                <source srcset="img/Desi_Memes_Hindi_Jokes_Indian_18.webp" type="image/webp" alt="Desi Memes">
                <source srcset="img/Desi_Memes_Hindi_Jokes_Indian_18.jpg" type="image/jpeg" alt="Desi Memes">
                <img src="img/Desi_Memes_Hindi_Jokes_Indian_18.jpg" alt="Desi Memes">
            </picture>
        </a>
        <div style="margin-left:30px;">
            <a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
            </a>
            <a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
                <h2 class="font-style1 mb-2 hover-underline">Desi Memes</h2>
            </a>
            <p class="mb-0 color-gray"><i>@Desi_Memes_Hindi_Jokes_Indian_18</i></p>
            <p class="fz-15 mb-0 color-gray"><i class="icon-users"></i> 55650 </p>
        </div>
    </div>
    <div class="channel-desc" style="padding-left:10px;padding-right:10px;">
        <p>• Best Telegram channel for <br>
        - Indian memes <br>
        - Hindi Jokes <br>
        - Desi Bakchodi</p>
    </div>
    <a class="telegram-btn reuse-button-colored" title="more about Desi Memes channel" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">View channel</a>
</div>
'''

soup = BeautifulSoup(html_code, 'html.parser')

channel_link_element = soup.find('a', title='Desi Memes')
channel_url = 'https://bestoftelegram.com' + channel_link_element['href']

channel_name_element = soup.find('h2', class_='font-style1')
channel_name = channel_name_element.text.strip()

channel_username_element = soup.find('p', class_='mb-0 color-gray').find('i')
channel_username = channel_username_element.text.strip('@')

members_element = soup.find('p', class_='fz-15 mb-0 color-gray').find('i', class_='icon-users')
members = members_element.next_sibling.strip()

description_element = soup.find('div', class_='channel-desc').find('p')
description = description_element.text.strip()

data = {
    'Channel Name': [channel_name],
    'Channel Username': [channel_username],
    'Members': [members],
    'Description': [description],
    'Link': [channel_url]
}

df = pd.DataFrame(data)
df
# Out:
#   Channel Name                  Channel Username Members  \
# 0   Desi Memes  Desi_Memes_Hindi_Jokes_Indian_18   55650
#
#                                          Description  \
# 0  • Best Telegram channel for \n        - Indian...
#
#                                                 Link
# 0  https://bestoftelegram.com/channels/Desi_Memes...

# %% [markdown]
# ## for page

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

link = 'https://bestoftelegram.com/channels/entertainment?page=1'

page = requests.get(link)

soup = BeautifulSoup(page.content, 'html.parser')

channel_link_element = soup.find('a', href=True)
channel_link = 'https://bestoftelegram.com' + channel_link_element['href']

channel_name_element = soup.find('h2')
channel_name = channel_name_element.text.strip()

channel_username_element = soup.find('p', class_='mb-0 color-gray').find('i')
channel_username = channel_username_element.text.strip('@')

members_element = soup.find('p', class_='fz-15 mb-0 color-gray').find('i', class_='icon-users')
members = members_element.next_sibling.strip()

description_element = soup.find('div', class_='channel-desc').find('p')
description = description_element.text.strip()

data = {
    'Channel Name': [channel_name],
    'Channel Username': [channel_username],
    'Members': [members],
    'Description': [description],
    'Link': [channel_url]
}

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 11
#       9 soup = BeautifulSoup(page.content, 'html.parser')
#      10 channel_link_element = soup.find('a', href=True)
# ---> 11 channel_link = 'https://bestoftelegram.com' + channel_link_element['href']
#      13 channel_name_element = soup.find('h2')
#      14 channel_name = channel_name_element.text.strip()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from bs4 import BeautifulSoup

html_code = '''
<div class="channel-area d-flex flex-wrap justify-content-between" style="padding:10px 15px;margin-bottom:10px;">
<a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
</a><div class="channel-head d-flex align-items-center" style="padding-right:10px;"><a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
<picture>
<source srcset="img/Desi_Memes_Hindi_Jokes_Indian_18.webp" type="image/webp" alt="Desi Memes">
<source srcset="img/Desi_Memes_Hindi_Jokes_Indian_18.jpg" type="image/jpeg" alt="Desi Memes">
<img src="img/Desi_Memes_Hindi_Jokes_Indian_18.jpg" alt="Desi Memes">
</picture>
</a><div style="margin-left:30px;"><a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
</a><a title="Desi Memes" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">
<h2 class="font-style1 mb-2 hover-underline">Desi Memes</h2>
</a>
<p class="mb-0 color-gray"><i>@Desi_Memes_Hindi_Jokes_Indian_18</i></p>
<p class="fz-15 mb-0 color-gray"><i class="icon-users"></i> 55650 </p>
</div>
</div>
<div class="channel-desc" style="padding-left:10px;padding-right:10px;">
<p>• Best Telegram channel for <br>
- Indian memes <br>
- Hindi Jokes <br>
- Desi Bakchodi</p>
</div>
<a class="telegram-btn reuse-button-colored" title="more about Desi Memes channel" href="/channels/Desi_Memes_Hindi_Jokes_Indian_18">View channel</a>

</div>
'''

soup = BeautifulSoup(html_code, 'html.parser')

channel_link_element = soup.find('a', href=True)
channel_link = 'https://bestoftelegram.com' + channel_link_element['href']

channel_name_element = soup.find('h2')
channel_name = channel_name_element.text.strip()

print('Channel Name:', channel_name)
print('Channel Link:', channel_link)
# Out:
# Channel Name: Desi Memes
# Channel Link: https://bestoftelegram.com/channels/Desi_Memes_Hindi_Jokes_Indian_18

# %% [markdown]
# ## for channel

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

channel = 'https://bestoftelegram.com/channels/Desi_Memes_Hindi_Jokes_Indian_18'
page = requests.get(channel)

soup = BeautifulSoup(page.content, 'html.parser')

channel_id_element = soup.find('i', class_='icon-id-card-o').find_next('br').previous_sibling
category_element = soup.find('i', class_='icon-filter').find_next('a')
language_element = soup.find('i', class_='icon-language').find_next('br').previous_sibling
members_element = soup.find('i', class_='icon-users').find_next('br').previous_sibling
date_added_element = soup.find('i', class_='icon-clock').find_next('br').previous_sibling
description_element = soup.find('h2', text='Channel Description').find_next('p')

channel_id = channel_id_element.strip().split(':')[1].strip()
category = category_element.text.strip()
language = language_element.strip()
members = members_element.strip()
date_added = date_added_element.strip()
description = description_element.text.strip()

data = {
    'Channel ID': [channel_id],
    'Category': [category],
    'Language': [language],
    'Members': [members],
    'Date Added': [date_added],
    'Description': [description],
    'Link': [channel]
}

df = pd.DataFrame(data)
df
# Out:
#                           Channel ID       Category  \
# 0  @Desi_Memes_Hindi_Jokes_Indian_18  Entertainment
#
#                     Language          Members                   Date Added  \
# 0  Language : Hindi, English  Members : 55650  • Best Telegram channel for
#
#                                          Description  \
# 0  • Best Telegram channel for \n- Indian memes \...
#
#                                                 Link
# 0  https://bestoftelegram.com/channels/Desi_Memes...

# %%
# %%time

channel_links=[]
for x in range(1,3):
    time.sleep(3)
    url=f'https://bestoftelegram.com/channels/entertainment?page={x}'
    request=requests.get(url)
    soup=BeautifulSoup(request,'html.parser')
    channel_name_element = soup.find('h2', class_='font-style1')
    channel_name = channel_name_element.text.strip()
    channels = soup.find('a', title=channel_name)
    for channel in channels:
        channel_links.append('https://bestoftelegram.com' + channel_link_element['href'])  
len(channel_links)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:6
#
# File C:\ProgramData\anaconda3\lib\site-packages\bs4\__init__.py:313, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
#     312     markup = markup.read()
# --> 313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#     316 ):
#     317     # Issue warnings for a couple beginner problems
#     318     # involving passing non-markup to Beautiful Soup.
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
# ...

# %%
page = requests.get(link)

soup = BeautifulSoup(html_code, 'html.parser')
# Out:
# []
