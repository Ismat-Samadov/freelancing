# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')

# %%
data
# Out:
#                   city state  zip_code income_2021 income_2000  land_area  \
# 0              Wasilla    AK   99654.0      $61943      $48226      11.70
# 1              Tanaina    AK   99654.0      $81202      $64491      27.10
# 2           Wind River    WY   82501.0      $52906      $30981    3051.30
# 3             Wheeling    WV   26003.0      $43794      $27388      13.90
# 4     Wisconsin Rapids    WI   54494.0      $42326      $34956      13.30
# ...                ...   ...       ...         ...         ...        ...
# 1814           Melrose    MA    2176.0     $126320      $62811       4.69
# 1815            Medway    MA    2053.0     $136640      $75135      11.50
# 1816           Medford    MA    2145.0     $108793      $52476       8.14
# 1817          Medfield    MA    2052.0     $174699      $83358       5.03
# 1818           Maynard    MA    1754.0     $113412      $60812       5.24
#
#       latitude  longitude                        population
# ...

# %%
data.to_excel('data.xlsx')
